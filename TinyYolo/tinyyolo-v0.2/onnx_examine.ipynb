# %%
import onnx_opcounter as opc
import onnx

model = onnx.load_model("tinyyolo-20210831.onnx")
params = opc.calculate_params(model)

print('Number of params:', params)
# Out:
# Number of params: 210206.0

# %%
# for n in model.graph.node:
#     print(n.op_type)
# Out:
# MultiThreshold
# Add
# Mul
# Conv
# Mul
# BatchNormalization
# MultiThreshold
# Add
# Mul
# Conv
# Mul
# BatchNormalization
# MultiThreshold
# Add
# Mul
# Conv
# Mul
# BatchNormalization
# MultiThreshold
# Add
# Mul
# Conv
# Mul
# BatchNormalization
# MultiThreshold
# Add
# Mul
# Conv
# Mul
# BatchNormalization
# MultiThreshold
# Add
# Mul
# Conv
# Mul
# BatchNormalization
# MultiThreshold
# Add
# Mul
# Conv
# Mul
# BatchNormalization
# MultiThreshold
# Add
# Mul
# Conv
# Mul
# BatchNormalization
# MultiThreshold
# Add
# Mul
# Conv
# Mul
# BatchNormalization
# MultiThreshold
# Add
# Mul
# Conv
# Mul
# BatchNormalization
# MultiThreshold
# Add
# Mul
# Conv
# Mul
# BatchNormalization
# MultiThreshold
# Add
# Mul
# MaxPool
# Conv
# Mul
# BatchNormalization
# MultiThreshold
# Add
# Mul
# Conv
# Mul
# BatchNormalization
# MultiThreshold
# Add
# Mul
# Conv
# Mul
# BatchNormalization
# MultiThreshold
# Add
# Mul
# Conv
# Mul
# BatchNormalization
# MultiThreshold
# Add
# Mul
# Conv
# Mul
# ...
