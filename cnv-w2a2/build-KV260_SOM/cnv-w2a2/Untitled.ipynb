# %%
import onnx
import onnxruntime as ort

import numpy as np
model = onnx.load("intermediate_models/dataflow_parent.onnx")
model.graph
# ort_sess = ort.InferenceSession(model.SerializeToString())
# outputs = ort_sess.run(None, {model.graph.input[0].name: x.numpy()})
# Out:
# node {
#   input: "global_in"
#   output: "wLvMb4"
#   name: "Transpose_0"
#   op_type: "Transpose"
#   attribute {
#     name: "perm"
#     ints: 0
#     ints: 2
#     ints: 3
#     ints: 1
#     type: INTS
#   }
# }
# node {
#   input: "wLvMb4"
#   output: "global_out"
#   name: "GenericPartition_0"
#   op_type: "StreamingDataflowPartition"
#   attribute {
#     name: "model"
#     s: "build-KV260_SOM/cnv-w2a2/intermediate_models/supported_op_partitions/partition_0.onnx"
#     type: STRING
#   }
#   attribute {
#     name: "partition_id"
#     i: 0
#     type: INT
#   }
#   attribute {
#     name: "slr"
#     i: -1
#     type: INT
#   }
#   attribute {
#     name: "mem_port"
#     s: ""
#     type: STRING
#   }
#   domain: "finn.custom_op.fpgadataflow"
# }
# name: "fuse-graph"
# input {
#   name: "global_in"
#   type {
#     tensor_type {
#       elem_type: 1
#       shape {
#         dim {
#           dim_value: 1
#         }
#         dim {
#           dim_value: 3
#         }
# ...
