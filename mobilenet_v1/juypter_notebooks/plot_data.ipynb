# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
dir = "../models/Mul/metrics"
for d in os.listdir(dir):
    title = d.replace('.csv','')
    df = pd.read_csv(os.path.join(dir,d))
    df.index = df['Unnamed: 0']
    plt.figure()
    df.plot(kind='bar',)
    plt.title(title)
    save = os.path.join(dir,"figures/")
    if not os.path.exists(save):
        os.makedirs(save)
    plt.savefig(os.path.join("{}/{}.png".format(save,title)))
