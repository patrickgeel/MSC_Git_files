# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import re

def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    return [ atoi(c) for c in re.split(r'(\d+)', text) ]

dir = "../models/Conv/metrics"
dirs = os.listdir(dir)
print(dirs)
for d in dirs:
#     print(d)
    if d != "figures":
        title = d.replace('.csv','')
        df = pd.read_csv(os.path.join(dir,d),index_col='Unnamed: 0')
        # df.index = df[]
        df.plot(kind='bar',)       

        plt.title(title)
        save = os.path.join(dir,"figures")
        if not os.path.exists(save):
            os.makedirs(save)
        # plt.legend(ncols = 4, loc = "best")
        plt.xlabel("")
        plt.show()
        plt.savefig(os.path.join("{}/{}.svg".format(save,title)),dpi= 500)
# Out:
# ['op_count_Conv_partition_1.csv', 'figures', 'resource_usage_hls_Conv.csv', 'op_count_Conv_partition_0.csv']
